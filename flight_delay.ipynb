# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/Flight data/flights.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  ...  AIRLINE_DELAY LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0  2015      1    1  ...            NaN                 NaN            NaN
# 1  2015      1    1  ...            NaN                 NaN            NaN
# 2  2015      1    1  ...            NaN                 NaN            NaN
# 3  2015      1    1  ...            NaN                 NaN            NaN
# 4  2015      1    1  ...            NaN                 NaN            NaN
#
# [5 rows x 31 columns]

# %%
df1 = df[:100000]

# %%
df1
# Out:
#        YEAR  MONTH  DAY  ...  AIRLINE_DELAY LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0      2015      1    1  ...            NaN                 NaN            NaN
# 1      2015      1    1  ...            NaN                 NaN            NaN
# 2      2015      1    1  ...            NaN                 NaN            NaN
# 3      2015      1    1  ...            NaN                 NaN            NaN
# 4      2015      1    1  ...            NaN                 NaN            NaN
# ...     ...    ...  ...  ...            ...                 ...            ...
# 99995  2015      1    7  ...            NaN                 NaN            NaN
# 99996  2015      1    7  ...            NaN                 NaN            NaN
# 99997  2015      1    7  ...            NaN                 NaN            NaN
# 99998  2015      1    7  ...            NaN                 NaN            NaN
# 99999  2015      1    7  ...            NaN                 NaN            NaN
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 100000 non-null  int64
#  1   MONTH                100000 non-null  int64
#  2   DAY                  100000 non-null  int64
#  3   DAY_OF_WEEK          100000 non-null  int64
#  4   AIRLINE              100000 non-null  object
#  5   FLIGHT_NUMBER        100000 non-null  int64
#  6   TAIL_NUMBER          99833 non-null   object
#  7   ORIGIN_AIRPORT       100000 non-null  object
#  8   DESTINATION_AIRPORT  100000 non-null  object
#  9   SCHEDULED_DEPARTURE  100000 non-null  int64
#  10  DEPARTURE_TIME       97702 non-null   float64
#  11  DEPARTURE_DELAY      97702 non-null   float64
#  12  TAXI_OUT             97629 non-null   float64
#  13  WHEELS_OFF           97629 non-null   float64
#  14  SCHEDULED_TIME       100000 non-null  float64
# ...

# %%
df1.DIVERTED.value_counts()
# Out:
# 0    99776
# 1      224
# Name: DIVERTED, dtype: int64

# %%
#pairplot

# %%
sns.pairplot(data = df1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.jointplot(data=df1, x="SCHEDULED_ARRIVAL" , y = "ARRIVAL_TIME", kind = "scatter")
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.heatmap(df1.isnull())

# %%
# import numpy as np
# corr = df1.corr()
# fig = plt.figure(figsize = (10,10))
# ax = fig.add_subplot(111)
# cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
# fig.colorbar(cax)
# ticks = np.arange(0,len(df1.columns),1)
# ax.set_xticks(ticks)
# plt.xticks(rotation=90)
# ax.set_yticks(ticks)
# ax.set_xticklabels(df1.columns)
# ax.set_yticklabels(df1.columns)
# plt.show()

# %%
df1.corr()
# Out:
#                      YEAR  MONTH  ...  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# YEAR                  NaN    NaN  ...                  NaN            NaN
# MONTH                 NaN    NaN  ...                  NaN            NaN
# DAY                   NaN    NaN  ...             0.033213       0.061960
# DAY_OF_WEEK           NaN    NaN  ...             0.033729      -0.050835
# FLIGHT_NUMBER         NaN    NaN  ...             0.076581       0.004246
# SCHEDULED_DEPARTURE   NaN    NaN  ...             0.186286      -0.042004
# DEPARTURE_TIME        NaN    NaN  ...             0.247325      -0.046406
# DEPARTURE_DELAY       NaN    NaN  ...             0.605289       0.210402
# TAXI_OUT              NaN    NaN  ...            -0.129879       0.119412
# WHEELS_OFF            NaN    NaN  ...             0.223010      -0.055273
# SCHEDULED_TIME        NaN    NaN  ...            -0.084673      -0.001975
# ELAPSED_TIME          NaN    NaN  ...            -0.118290       0.014470
# ...

# %%
df1[df1.columns[:]].corr()["ARRIVAL_DELAY"][:].sort_values(ascending= False)
# Out:
# ARRIVAL_DELAY          1.000000
# DEPARTURE_DELAY        0.950838
# AIRLINE_DELAY          0.592718
# LATE_AIRCRAFT_DELAY    0.572956
# AIR_SYSTEM_DELAY       0.259700
# TAXI_OUT               0.245363
# WEATHER_DELAY          0.235906
# DEPARTURE_TIME         0.223654
# WHEELS_OFF             0.217344
# TAXI_IN                0.170073
# SCHEDULED_DEPARTURE    0.154951
# SCHEDULED_ARRIVAL      0.140565
# WHEELS_ON              0.088131
# ARRIVAL_TIME           0.076791
# DAY                    0.070770
# DAY_OF_WEEK            0.067520
# FLIGHT_NUMBER          0.056163
# ELAPSED_TIME           0.048448
# SECURITY_DELAY         0.006070
# AIR_TIME              -0.002742
# SCHEDULED_TIME        -0.022043
# DISTANCE              -0.023821
# YEAR                        NaN
# MONTH                       NaN
# DIVERTED                    NaN
# CANCELLED                   NaN
# Name: ARRIVAL_DELAY, dtype: float64

# %%
df1 = df1.drop(['YEAR','FLIGHT_NUMBER','AIRLINE','DISTANCE','TAIL_NUMBER','TAXI_OUT', 'SCHEDULED_TIME','DEPARTURE_TIME','WHEELS_OFF','ELAPSED_TIME', 'AIR_TIME','WHEELS_ON','DAY_OF_WEEK','TAXI_IN','CANCELLATION_REASON'], axis = 1)

# %%
df1
# Out:
#        MONTH  DAY  ... LATE_AIRCRAFT_DELAY WEATHER_DELAY
# 0          1    1  ...                 NaN           NaN
# 1          1    1  ...                 NaN           NaN
# 2          1    1  ...                 NaN           NaN
# 3          1    1  ...                 NaN           NaN
# 4          1    1  ...                 NaN           NaN
# ...      ...  ...  ...                 ...           ...
# 99995      1    7  ...                 NaN           NaN
# 99996      1    7  ...                 NaN           NaN
# 99997      1    7  ...                 NaN           NaN
# 99998      1    7  ...                 NaN           NaN
# 99999      1    7  ...                 NaN           NaN
#
# [100000 rows x 16 columns]

# %%
df1.columns
# Out:
# Index(['MONTH', 'DAY', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_DELAY', 'SCHEDULED_ARRIVAL',
#        'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
df1.shape
# Out:
# (100000, 16)

# %%
df1 = df1.fillna(df1.mean())

# %%
df1.isnull().sum()
# Out:
# MONTH                  0
# DAY                    0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_DELAY        0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# AIR_SYSTEM_DELAY       0
# SECURITY_DELAY         0
# AIRLINE_DELAY          0
# LATE_AIRCRAFT_DELAY    0
# WEATHER_DELAY          0
# dtype: int64

# %%
result = []
for row in df1["ARRIVAL_DELAY"]:
    if row>15:
        result.append(1)
    else:
        result.append(0)
df1["result"] = result

# %%
df1
# Out:
#        MONTH  DAY ORIGIN_AIRPORT  ... LATE_AIRCRAFT_DELAY  WEATHER_DELAY  result
# 0          1    1            ANC  ...           26.014556       2.751971       0
# 1          1    1            LAX  ...           26.014556       2.751971       0
# 2          1    1            SFO  ...           26.014556       2.751971       0
# 3          1    1            LAX  ...           26.014556       2.751971       0
# 4          1    1            SEA  ...           26.014556       2.751971       0
# ...      ...  ...            ...  ...                 ...            ...     ...
# 99995      1    7            ATL  ...           26.014556       2.751971       0
# 99996      1    7            LAS  ...           26.014556       2.751971       0
# 99997      1    7            SFO  ...           26.014556       2.751971       0
# 99998      1    7            ORD  ...           26.014556       2.751971       0
# 99999      1    7            HOU  ...           26.014556       2.751971       0
#
# ...

# %%
df1["result"].value_counts()
# Out:
# 0    63779
# 1    36221
# Name: result, dtype: int64

# %%
df1=df1.drop(['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'ARRIVAL_TIME', 'ARRIVAL_DELAY'],axis=1)

# %%
df1
# Out:
#        MONTH  DAY  ...  WEATHER_DELAY  result
# 0          1    1  ...       2.751971       0
# 1          1    1  ...       2.751971       0
# 2          1    1  ...       2.751971       0
# 3          1    1  ...       2.751971       0
# 4          1    1  ...       2.751971       0
# ...      ...  ...  ...            ...     ...
# 99995      1    7  ...       2.751971       0
# 99996      1    7  ...       2.751971       0
# 99997      1    7  ...       2.751971       0
# 99998      1    7  ...       2.751971       0
# 99999      1    7  ...       2.751971       0
#
# [100000 rows x 13 columns]

# %%
X = df1.iloc[:,:-1]
y= df1.iloc[:,-1]

# %%
X.head()
# Out:
#    MONTH  DAY  ...  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0      1    1  ...            26.014556       2.751971
# 1      1    1  ...            26.014556       2.751971
# 2      1    1  ...            26.014556       2.751971
# 3      1    1  ...            26.014556       2.751971
# 4      1    1  ...            26.014556       2.751971
#
# [5 rows x 12 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: result, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaled_features = StandardScaler().fit_transform(X_train, X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
# clf.score()

# %%
from sklearn.metrics import roc_auc_score
pred = clf.predict_proba(X_test)
pred = pred[:,1]
auc_score = roc_auc_score(y_test, pred)
auc_score
# Out:
# 0.998070195188694
